# %%
import csv
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../HosPayment.csv')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#   State                       Hospital name     Price  Average  Difference
# 0    AK        ALASKA NATIVE MEDICAL CENTER  17210.75  18593.5    -1382.75
# 1    AK            ALASKA REGIONAL HOSPITAL  18662.00  18593.5       68.50
# 2    AK          BARTLETT REGIONAL HOSPITAL  17406.75  18593.5    -1186.75
# 3    AK  CENTRAL PENINSULA GENERAL HOSPITAL  18001.75  18593.5     -591.75
# 4    AK    CORDOVA COMMUNITY MEDICAL CENTER  19725.50  18593.5     1132.00

# %%
for row in df.itertuples():
    df.loc[row.Index, 'Rating'] = -4.7*float(row[8]) - 3.5*float(row[9])

# %%
df['Ranking'] = df['Difference']

# %%
df.to_csv('HospitalSpendingRanking.csv')

# %%
df
# Out:
#      State                                      Hospital name        Price  \
# 0       AK                       ALASKA NATIVE MEDICAL CENTER  17210.75000
# 1       AK                           ALASKA REGIONAL HOSPITAL  18662.00000
# 2       AK                         BARTLETT REGIONAL HOSPITAL  17406.75000
# 3       AK                 CENTRAL PENINSULA GENERAL HOSPITAL  18001.75000
# 4       AK                   CORDOVA COMMUNITY MEDICAL CENTER  19725.50000
# 5       AK                        FAIRBANKS MEMORIAL HOSPITAL  17058.00000
# 6       AK                                 KANAKANAK HOSPITAL  19725.50000
# 7       AK                             MANIILAQ HEALTH CENTER  19725.50000
# 8       AK                     MAT-SU REGIONAL MEDICAL CENTER  16693.25000
# 9       AK                              MT EDGECUMBE HOSPITAL  19725.50000
# 10      AK                     NORTON SOUND REGIONAL HOSPITAL  17662.75000
# ...
