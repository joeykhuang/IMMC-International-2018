# %%
import pandas as pd

# %%
df = pd.DataFrame(pd.read_csv('../Data/1.csv'))

# %%
df = df.dropna(axis=0, how='all')

# %%
df = df.set_index(['State', 'Disease'])

# %%
df
# Out:
#                                                           Total number of discharges: N  \
# State Disease
# AZ    Acute myocardial infarction                                               11239.0
#       Congestive heart failure, nonhypertensive                                 12965.0
#       Acute cerebrovascular disease                                             11244.0
#       Pneumonia (except that caused by tuberculosis a...                        17064.0
#       Chronic obstructive pulmonary disease and bronc...                         8884.0
# AR    Acute myocardial infarction                                                6618.0
#       Congestive heart failure, nonhypertensive                                 10232.0
#       Acute cerebrovascular disease                                              6099.0
#       Pneumonia (except that caused by tuberculosis a...                        12697.0
# ...
