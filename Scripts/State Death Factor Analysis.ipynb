# %%
import pandas as pd
from collections import OrderedDict, defaultdict
df = pd.DataFrame(pd.read_csv('~/Desktop/DF.csv'))
df = df.dropna(axis=0, how='all')
df = df.set_index(['State', 'Disease'])

# %%
df
# Out:
#                                                           Total number of discharges: N  \
# State Disease
# AZ    Acute myocardial infarction                                                 11239
#       Congestive heart failure, nonhypertensive                                   12965
#       Acute cerebrovascular disease                                               11244
#       Pneumonia (except that caused by tuberculosis a...                          17064
#       Chronic obstructive pulmonary disease and bronc...                           8884
# AR    Acute myocardial infarction                                                  6618
#       Congestive heart failure, nonhypertensive                                   10232
#       Acute cerebrovascular disease                                                6099
#       Pneumonia (except that caused by tuberculosis a...                          12697
# ...
